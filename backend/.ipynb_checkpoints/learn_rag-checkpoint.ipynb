# %%
with open("ironchat_info.txt", "r") as f:
    text = f.read()
print(text)
# Out:
# # IronChat - Complete Project Documentation
#
# ## 1. Project Overview
# IronChat is a modern, responsive, and elegant AI chatbot application designed to provide quick questions, helpful answers, and smooth conversational flows. It leverages the raw speed of Llama-3 through Groq's APIs to provide real-time streaming answers. IronChat acts as an advanced intelligent assistant that can answer general knowledge questions, perform live web searches for up-to-date information, and read uploaded documents (PDFs) to answer questions based on the user's private data.
#
# ## 2. Core Features
# - **Blazing Fast AI Responses:** Powered by Llama-3 70b via Groq API for near-instant inference and low latency.
# - **Premium UI/UX:** Built with Tailwind CSS v4, featuring a glassmorphic dashboard, responsive layout, dark/light mode toggles, and smooth micro-animations.
# - **Secure Authentication:** Built-in user sign up, login, and session management using JWT access and refresh tokens, with passwords hashed via Argon2.
# - **Optimized Backend:** A robust FastAPI backend integrated with PostgreSQL (via Supabase), using advanced async SQLModel techniques to minimize latency.
# - **Streaming Messages:** Messages are streamed to the frontend via Server-Sent Events (SSE) for a typewriter-like feel, so users don't have to wait for the entire response to generate before reading it.
# - **Web Search Integration:** Can intelligently decide when a user's prompt requires real-time information and perform live web searches using Tavily.
# - **Retrieval-Augmented Generation (RAG):** Allows users to upload PDF documents, which the chatbot reads, processes, and uses as context to answer specific questions about the document's content.
#
# ## 3. Technology Stack
#
# ### Frontend (Client-Side)
# - **Framework:** React 19 and Vite 8 for fast builds and hot module replacement.
# - **Styling:** Tailwind CSS v4 for utility-first, highly responsive, and premium UI design.
# - **Markdown Rendering:** `react-markdown` and `remark-gfm` are used to securely and beautifully render Markdown responses from the AI.
# - **API Communication:** Custom Fetch wrappers are used to handle JWT authentication and Server-Sent Events (SSE) for real-time text streaming.
#
# ### Backend (Server-Side)
# - **Language & Framework:** Python 3.13 and FastAPI, chosen for high performance and native async support.
# - **Database (Relational):** PostgreSQL, hosted on Supabase.
# - **ORM (Object-Relational Mapping):** SQLModel and SQLAlchemy 2.0 with `asyncpg` for high-speed asynchronous database operations.
# - **Migrations:** Alembic is used to manage database schema changes.
# - **Authentication:** PyJWT is used for JSON Web Tokens, and `pwdlib` with Argon2 is used for secure password hashing.
#
# ### AI, Machine Learning, and External APIs
# - **Large Language Model (LLM):** Groq API running Llama-3 70b.
# - **Web Search API:** Tavily (`tavily-python`), an AI-focused search engine API.
# - **Vector Embeddings:** Voyage AI (`voyageai`), specifically the `voyage-3-lite` model, used to convert text into mathematical vectors.
# - **Vector Database:** Qdrant (`qdrant-client`), used for fast semantic similarity search over document embeddings.
# - **Document Parsing:** PyMuPDF (`fitz`), used to extract raw text accurately from uploaded PDF files.
# - **File Storage:** Supabase Storage, used as a secure bucket to store the raw PDF files uploaded by users.
#
# ## 4. How the RAG (Document Chat) Pipeline Works
# Retrieval-Augmented Generation (RAG) is the feature that allows IronChat to read and answer questions about PDFs.
# 1. **Upload & Storage:** The user uploads a PDF in the React frontend. The FastAPI backend receives it and stores the raw file in a Supabase Storage bucket.
# 2. **Text Extraction:** The backend uses PyMuPDF to extract text from the PDF, page by page.
# 3. **Chunking:** The extracted text is split into smaller, overlapping "chunks" (usually around 700 characters) to ensure the AI gets precise context without being overwhelmed.
# 4. **Embedding:** The text chunks are sent to the Voyage AI API, which converts the human text into vector embeddings (lists of numbers representing meaning).
# 5. **Vector Storage:** These vectors, along with metadata (like page numbers and chat IDs), are saved in the Qdrant Vector Database.
# 6. **Retrieval (Answering):** When the user asks a question, IronChat converts the question into a vector using Voyage AI, searches Qdrant for the closest matching chunks, and feeds those chunks into the Groq Llama-3 prompt so it can generate an accurate answer based on the document.
#
# ## 5. How the Web Search Pipeline Works
# IronChat does not just rely on its pre-trained knowledge; it can search the live internet.
# 1. **Decision Phase:** When a user sends a message, a hidden system prompt asks the LLM: "Does this require a live web search? Answer yes or no."
# 2. **Search Phase:** If the LLM says yes, the backend uses the Tavily API to search the web for the query and retrieves the top results (titles, URLs, and text snippets).
# 3. **Augmentation:** The search results are injected into the context of the main conversation.
# 4. **Generation:** The Groq Llama-3 model reads the search results, writes a comprehensive answer, and includes inline citations (e.g., [1], [2]) linking back to the source URLs.
#
# ## 6. Security and Deployment
# - **CORS & Origins:** The backend is strictly configured to only accept requests from the deployed frontend URL to prevent cross-site request forgery.
# - **Deployment:** The frontend is deployed and hosted on Vercel. The backend is deployed and hosted on Render.
# - **Database Hosting:** The PostgreSQL relational database and the file storage buckets are hosted on Supabase.

# %%
def chunking(text, size=500, overlap=50):
    chunks = []
    start = 1
    while start < len(text):
        end  = start + size
        chunk = text[start:end]
        if chunk.strip():
            chunks.append(chunk)
        start += size - overlap
    return chunks

chunks = chunking(text)
# Out:
# Chunk 0
#  IronChat - Complete Project Documentation
#
# ## 1. Project Overview
# IronChat is a modern, responsive, and elegant AI chatbot application designed to provide quick questions, helpful answers, and smooth conversational flows. It leverages the raw speed of Llama-3 through Groq's APIs to provide real-time streaming answers. IronChat acts as an advanced intelligent assistant that can answer general knowledge questions, perform live web searches for up-to-date information, and read uploaded documents (
# Chunk 1
# to-date information, and read uploaded documents (PDFs) to answer questions based on the user's private data.
#
# ## 2. Core Features
# - **Blazing Fast AI Responses:** Powered by Llama-3 70b via Groq API for near-instant inference and low latency.
# - **Premium UI/UX:** Built with Tailwind CSS v4, featuring a glassmorphic dashboard, responsive layout, dark/light mode toggles, and smooth micro-animations.
# - **Secure Authentication:** Built-in user sign up, login, and session management using JWT access
# Chunk 2
# up, login, and session management using JWT access and refresh tokens, with passwords hashed via Argon2.
# - **Optimized Backend:** A robust FastAPI backend integrated with PostgreSQL (via Supabase), using advanced async SQLModel techniques to minimize latency.
# - **Streaming Messages:** Messages are streamed to the frontend via Server-Sent Events (SSE) for a typewriter-like feel, so users don't have to wait for the entire response to generate before reading it.
# - **Web Search Integration:** Can in
# Chunk 3
# e reading it.
# - **Web Search Integration:** Can intelligently decide when a user's prompt requires real-time information and perform live web searches using Tavily.
# - **Retrieval-Augmented Generation (RAG):** Allows users to upload PDF documents, which the chatbot reads, processes, and uses as context to answer specific questions about the document's content.
#
# ## 3. Technology Stack
#
# ### Frontend (Client-Side)
# - **Framework:** React 19 and Vite 8 for fast builds and hot module replacement.
# - **S
# Chunk 4
#  for fast builds and hot module replacement.
# - **Styling:** Tailwind CSS v4 for utility-first, highly responsive, and premium UI design.
# - **Markdown Rendering:** `react-markdown` and `remark-gfm` are used to securely and beautifully render Markdown responses from the AI.
# - **API Communication:** Custom Fetch wrappers are used to handle JWT authentication and Server-Sent Events (SSE) for real-time text streaming.
#
# ### Backend (Server-Side)
# - **Language & Framework:** Python 3.13 and FastAPI, cho
# Chunk 5
# nguage & Framework:** Python 3.13 and FastAPI, chosen for high performance and native async support.
# - **Database (Relational):** PostgreSQL, hosted on Supabase.
# - **ORM (Object-Relational Mapping):** SQLModel and SQLAlchemy 2.0 with `asyncpg` for high-speed asynchronous database operations.
# - **Migrations:** Alembic is used to manage database schema changes.
# - **Authentication:** PyJWT is used for JSON Web Tokens, and `pwdlib` with Argon2 is used for secure password hashing.
#
# ### AI, Machine Le
# Chunk 6
# d for secure password hashing.
#
# ### AI, Machine Learning, and External APIs
# - **Large Language Model (LLM):** Groq API running Llama-3 70b.
# - **Web Search API:** Tavily (`tavily-python`), an AI-focused search engine API.
# - **Vector Embeddings:** Voyage AI (`voyageai`), specifically the `voyage-3-lite` model, used to convert text into mathematical vectors.
# - **Vector Database:** Qdrant (`qdrant-client`), used for fast semantic similarity search over document embeddings.
# - **Document Parsing:** Py
# Chunk 7
# er document embeddings.
# - **Document Parsing:** PyMuPDF (`fitz`), used to extract raw text accurately from uploaded PDF files.
# - **File Storage:** Supabase Storage, used as a secure bucket to store the raw PDF files uploaded by users.
#
# ## 4. How the RAG (Document Chat) Pipeline Works
# Retrieval-Augmented Generation (RAG) is the feature that allows IronChat to read and answer questions about PDFs.
# 1. **Upload & Storage:** The user uploads a PDF in the React frontend. The FastAPI backend receives i
# Chunk 8
# the React frontend. The FastAPI backend receives it and stores the raw file in a Supabase Storage bucket.
# 2. **Text Extraction:** The backend uses PyMuPDF to extract text from the PDF, page by page.
# 3. **Chunking:** The extracted text is split into smaller, overlapping "chunks" (usually around 700 characters) to ensure the AI gets precise context without being overwhelmed.
# 4. **Embedding:** The text chunks are sent to the Voyage AI API, which converts the human text into vector embeddings (lists
# Chunk 9
# verts the human text into vector embeddings (lists of numbers representing meaning).
# 5. **Vector Storage:** These vectors, along with metadata (like page numbers and chat IDs), are saved in the Qdrant Vector Database.
# 6. **Retrieval (Answering):** When the user asks a question, IronChat converts the question into a vector using Voyage AI, searches Qdrant for the closest matching chunks, and feeds those chunks into the Groq Llama-3 prompt so it can generate an accurate answer based on the documen
# Chunk 10
# n generate an accurate answer based on the document.
#
# ## 5. How the Web Search Pipeline Works
# IronChat does not just rely on its pre-trained knowledge; it can search the live internet.
# 1. **Decision Phase:** When a user sends a message, a hidden system prompt asks the LLM: "Does this require a live web search? Answer yes or no."
# 2. **Search Phase:** If the LLM says yes, the backend uses the Tavily API to search the web for the query and retrieves the top results (titles, URLs, and text snippets)
# Chunk 11
#  the top results (titles, URLs, and text snippets).
# 3. **Augmentation:** The search results are injected into the context of the main conversation.
# 4. **Generation:** The Groq Llama-3 model reads the search results, writes a comprehensive answer, and includes inline citations (e.g., [1], [2]) linking back to the source URLs.
#
# ## 6. Security and Deployment
# - **CORS & Origins:** The backend is strictly configured to only accept requests from the deployed frontend URL to prevent cross-site request
# Chunk 12
# ployed frontend URL to prevent cross-site request forgery.
# - **Deployment:** The frontend is deployed and hosted on Vercel. The backend is deployed and hosted on Render.
# - **Database Hosting:** The PostgreSQL relational database and the file storage buckets are hosted on Supabase.

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2") 
vectors = model.encode(chunks)  

print(f"Number of vectors: {len(vectors)}")
print(f"Length of one vector: {len(vectors[0])}")
print(vectors)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Number of vectors: 13
# Length of one vector: 384
# [[-0.05152991 -0.01476924 -0.04759979 ...  0.04126653 -0.02887441
#   -0.01083683]
#  [-0.09445109 -0.02132373 -0.03045554 ...  0.00414    -0.01135906
#    0.06416095]
#  [-0.05513256 -0.03179579 -0.07248069 ... -0.00272684 -0.03015354
#    0.02696545]
#  ...
#  [-0.0205675  -0.00371994 -0.01908317 ... -0.00324702  0.00330642
#   -0.0355993 ]
#  [-0.11137916 -0.02138437 -0.04521354 ...  0.00915523  0.06772952
#    0.06769417]
#  [-0.03749055 -0.02715368 -0.03462127 ... -0.05516433  0.08381098
#    0.08043496]]

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct

client = QdrantClient(
    url=settings.QDRANT_URL,
    api_key=settings.QDRANT_API_KEY,
)

print(len(vectors[0])) 

COLLECTION_NAME = "ironchat_docs"

client.recreate_collection(
    collection_name=COLLECTION_NAME,
    vectors_config=VectorParams(size=len(vectors[0]), distance=Distance.COSINE),
)

points = [
    PointStruct(
        id=i,
        vector=vectors[i],
        payload={"text": chunks[i]}
    )
    for i in range(len(chunks))
]

client.upsert(collection_name=COLLECTION_NAME, points=points)
print(f"Uploaded {len(points)} points to Qdrant")
# Out:
# /var/folders/kn/7pgm4glj1bv1r1g2ng4bhpl00000gn/T/ipykernel_98339/3097973135.py:11: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# Uploaded 13 points to Qdrant

# %%
question = "What is IronChat?"

question_response = vo.embed([question], model="voyage-3", input_type="query")
question_vector = question_response.embeddings[0]

response = client.query_points(collection_name=COLLECTION_NAME, query=question_vector, limit=3)
for r in response:
    print(f"Score: {r.score:.4f}")
    print(r.payload["text"])
    print("---")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[25], line 6
#       2
#       3 question_response = vo.embed([question], model="voyage-3", input_type="query")
#       4 question_vector = question_response.embeddings[0]
#       5
# ----> 6 response = client.query_points(collection_name=COLLECTION_NAME, query=question_vector, limit=3)
#       7 for r in response:
#       8     print(f"Score: {r.score:.4f}")
#       9     print(r.payload["text"])
#
# File ~/Documents/github/sulemangulzar/AI Engineering/Projects/IronChat/backend/.venv/lib/python3.13/site-packages/qdrant_client/qdrant_client.py:423, in QdrantClient.query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     408         else:
#     409             prefetch = (
#     410                 next(
#     411                     iter(
#    (...)    420                 else None
#     421             )
# --> 423 return self._client.query_points(
#     424     collection_name=collection_name,
#     425     query=query,
#     426     prefetch=prefetch,
#     427     query_filter=query_filter,
#     428     search_params=search_params,
#     429     limit=limit,
#     430     offset=offset,
#     431     with_payload=with_payload,
#     432     with_vectors=with_vectors,
#     433     score_threshold=score_threshold,
#     434     using=using,
#     435     lookup_from=lookup_from,
#     436     consistency=consistency,
#     437     shard_key_selector=shard_key_selector,
#     438     timeout=timeout,
#     439     **kwargs,
#     440 )
#
# File ~/Documents/github/sulemangulzar/AI Engineering/Projects/IronChat/backend/.venv/lib/python3.13/site-packages/qdrant_client/qdrant_remote.py:585, in QdrantRemote.query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     568     lookup_from = GrpcToRest.convert_lookup_location(lookup_from)
#     570 query_request = models.QueryRequest(
#     571     shard_key=shard_key_selector,
#     572     prefetch=prefetch,
#    (...)    582     lookup_from=lookup_from,
#     583 )
# --> 585 query_result = self.http.search_api.query_points(
#     586     collection_name=collection_name,
#     587     consistency=consistency,
#     588     timeout=timeout,
#     589     query_request=query_request,
#     590 )
#     592 result: models.QueryResponse | None = query_result.result
#     593 assert result is not None, "Search returned None"
#
# File ~/Documents/github/sulemangulzar/AI Engineering/Projects/IronChat/backend/.venv/lib/python3.13/site-packages/qdrant_client/http/api/search_api.py:783, in SyncSearchApi.query_points(self, collection_name, consistency, timeout, query_request)
#     773 def query_points(
#     774     self,
#     775     collection_name: str,
#    (...)    778     query_request: m.QueryRequest = None,
#     779 ) -> m.InlineResponse20024:
#     780     """
#     781     Universally query points. This endpoint covers all capabilities of search, recommend, discover, filters. But also enables hybrid and multi-stage queries.
#     782     """
# --> 783     return self._build_for_query_points(
#     784         collection_name=collection_name,
#     785         consistency=consistency,
#     786         timeout=timeout,
#     787         query_request=query_request,
#     788     )
#
# File ~/Documents/github/sulemangulzar/AI Engineering/Projects/IronChat/backend/.venv/lib/python3.13/site-packages/qdrant_client/http/api/search_api.py:181, in _SearchApi._build_for_query_points(self, collection_name, consistency, timeout, query_request)
#     179 if "Content-Type" not in headers:
#     180     headers["Content-Type"] = "application/json"
# --> 181 return self.api_client.request(
#     182     type_=m.InlineResponse20024,
#     183     method="POST",
#     184     url="/collections/{collection_name}/points/query",
#     185     headers=headers if headers else None,
#     186     path_params=path_params,
#     187     params=query_params,
#     188     content=body,
#     189 )
#
# File ~/Documents/github/sulemangulzar/AI Engineering/Projects/IronChat/backend/.venv/lib/python3.13/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/Documents/github/sulemangulzar/AI Engineering/Projects/IronChat/backend/.venv/lib/python3.13/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Wrong input: Vector dimension error: expected dim: 384, got 1024"},"time":0.000393263}'
