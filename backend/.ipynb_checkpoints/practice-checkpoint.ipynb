# %%
ground_truth = {"doc_1","doc_2","doc_5",}
retrived = {"doc_1","doc_2","doc_3",}

true_positives = ground_truth & retrived

print(true_positives)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 ground_truth = ["doc_1","doc_3","doc_3",]
#       2 retrived = ["doc_1","doc_3","doc_3",]
# ----> 3 true_positives = ground_truth & retrived
#       4 print(true_positives)
#
# TypeError: unsupported operand type(s) for &: 'list' and 'list'
